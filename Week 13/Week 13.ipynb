# %%
import numpy as np
#this is a python function called y_hat
y_hat = lambda x,m,b:1/(1+np.exp(-m*x+b))

# %%
#data to predict
x_val = 32
y_true = 0

#parameters to use
curr_m = .7
curr_b = 50

#get the prediction
pred = y_hat(x_val,curr_m,curr_b)
print(pred)
# Out:
# 1.031507284889618e-12

# %%
#this is a python function called cost
cost = lambda y,y_hat: -((1-y)*np.log(1-y_hat) + y*np.log(y_hat))

cost(y_true,pred)
# Out:
# np.float64(1.0315082121797649e-12)
