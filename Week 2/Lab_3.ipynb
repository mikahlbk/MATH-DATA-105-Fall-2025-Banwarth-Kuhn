# %% [markdown]
# <div style="font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, 'Helvetica Neue', Arial; padding: 20px; border-radius: 16px; box-shadow: 0 10px 25px rgba(0,0,0,.08); background: linear-gradient(135deg,#fff 0%, #f0f7ff 60%, #e8fff4 100%);">
#   <h1 style="margin:0 0 8px; font-size: 2rem;">
#     👋 Welcome to Math 105 Lab 3!
#   </h1>
# <div style="margin-top:16px; padding:12px 14px; border:1px dashed #94a3b8; border-radius:12px; background:#fff;">
#     <strong>Today’s mission:</strong> More practice with rate of change.</div>
#
#   <div style="margin-top:14p

# %% [markdown]
# You will need this table:
# | Month    | Average Storage (acre-ft) |
# |----------|----------------------------|
# | Jul (0)  | 353709.68 |
# | Aug (1)  | 330651.61 |
# | Sep (2)  | 300273.33 |
# | Oct (3)  | 274212.90 |
# | Nov (4)  | 250220.00 |
# | Dec (5)  | 237735.48 |
# | Jan (6)  | 245438.71 |
# | Feb (7)  | 265332.14 |
# | Mar (8)  | 276225.81 |
# | Apr (9)  | 278993.33 |
# | May (10) | 329241.94 |
# | Jun (11) | 361083.33 |
# | Jul (12) | 349877.42 |

# %% [markdown]
# Also, here is the graph:

# %%
#Create vectors to hold the data
months_labels = [
    "Jul (0)", "Aug (1)", "Sep (2)", "Oct (3)", "Nov (4)", "Dec (5)",
    "Jan (6)", "Feb (7)", "Mar (8)", "Apr (9)", "May (10)", "Jun (11)", "Jul (12)"
]
storage_values = [
    353709.68, 330651.61, 300273.33, 274212.90, 250220.00, 237735.48,
    245438.71, 265332.14, 276225.81, 278993.33, 329241.94, 361083.33,349877.42
]

#we need the matplotlib library to make the plot
import matplotlib.pyplot as plt
#do the plotting
plt.figure(figsize=(10,6))#this makes the figure easier to see
#plt.plot(input_values,output_values,marker makes circles at each point)
plt.plot(months_labels, storage_values, marker='o')
plt.xlabel("Month")
plt.ylabel("Average Storage (acre-ft)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#define a function that will do the Rate of Change computation for us
def compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val):
    input_change = final_input_val-start_input_val#denominator, i.e. change in input
    output_change = final_output_val-start_output_val#numerator, i.e. change in ouput
    return output_change/input_change#change in output/change in input

# %% [markdown]
# <b>Exercise 2.1.2:<b>
#
# (A) Calculate the average rate of change in acre-feet of water over 6-month intervals, starting with July 2024.
#
# Solution:
#
# The first 6 month interval is July 2024 (month 0) - January 2025 (month 6).
# $$\text{Rate of Change (first 6 months)} = \frac{\text{change in output}}{\text{change in input}} = \frac{a(\text{January 2025})-a(\text{July 2024})}{6-0} = ???$$

# %%
#have Python do the math
final_input_val = 2
start_input_val = 1
final_output_val = 5
start_output_val = 3
RoC_first_6 = compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val)
print("The Rate of Change (first 6 months) is equal to {}".format(RoC_first_6))
# Out:
# The Rate of Change (first 6 months) is equal to 2.0

# %% [markdown]
# The second 6 month interval is January 2025 (month 6) - July 2025 (month 12).
# $$\text{Rate of Change (second 6 months)} = \frac{\text{change in output}}{\text{change in input}} = \frac{???}{???} = ???$$

# %%
#have Python do the math
#have Python do the math
final_input_val = 2
start_input_val = 1
final_output_val = 5
start_output_val = 3
RoC_second_6 = compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val)
print("The Rate of Change (second 6 months) is equal to {}".format(RoC_second_6))
# Out:
# The Rate of Change (second 6 months) is equal to 2.0

# %% [markdown]
# <b>Exercise 2.1.2:<b>
#
# (B) Calculate the average rate of change in acre-feet of water over 4-month intervals, starting with July 2024.
#
# Solution:
#
# The first 4 month interval is July 2024 (month 0) - November 2024 (month 4).
# $$\text{Rate of Change (first 4 months)} = \frac{\text{change in output}}{\text{change in input}} = \frac{a(\text{November 2024})-a(\text{July 2024})}{4-0} = ???$$

# %%
#have Python do the math
final_input_val = 2
start_input_val = 1
final_output_val = 5
start_output_val = 3
RoC_first_4 = compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val)
print("The Rate of Change (first 4 months) is equal to {}".format(RoC_first_4))
# Out:
# The Rate of Change (first 4 months) is equal to 2.0

# %% [markdown]
# The second 4 month interval is November 2024 (month 4) - March 2025 (month 8).
# $$\text{Rate of Change (second 4 months)} = \frac{\text{change in output}}{\text{change in input}} = \frac{???}{???} = ???$$

# %%
#have Python do the math
final_input_val = 2
start_input_val = 1
final_output_val = 5
start_output_val = 3
RoC_second_4 = compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val)
print("The Rate of Change (second 4 months) is equal to {}".format(RoC_second_4))
# Out:
# The Rate of Change (second 4 months) is equal to 2.0

# %% [markdown]
# The third 4 month interval is ??? 2025 (month ???) - ??? 2025 (month ???).
# $$\text{Rate of Change (third 4 months)} = \frac{\text{change in output}}{\text{change in input}} = \frac{???}{???} = ???$$

# %%
#have Python do the math
final_input_val = 2
start_input_val = 1
final_output_val = 5
start_output_val = 3
RoC_third_4 = compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val)
print("The Rate of Change (third 4 months) is equal to {}".format(RoC_third_4))
# Out:
# The Rate of Change (third 4 months) is equal to 2.0

# %% [markdown]
# <b>Exercise 2.1.2:<b>
#
# (C) Calculate the average rate of change in acre-feet of water over 2-month intervals, starting with July 2024.
#
# Solution:
#
# The first 2 month interval is July 2024 (month 0) - Septmeber 2024 (month 2).
# $$\text{Rate of Change (first 2 months)} = \frac{\text{change in output}}{\text{change in input}} = \frac{a(\text{September 2024})-a(\text{July 2024})}{2-0} = ???$$

# %%
#have Python do the math
final_input_val = 2
start_input_val = 1
final_output_val = 5
start_output_val = 3
RoC_first_2 = compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val)
print("The Rate of Change (first 2 months) is equal to {}".format(RoC_first_2))
# Out:
# The Rate of Change (first 2 months) is equal to 2.0

# %% [markdown]
# The second 2 month interval is ??? 2024 (month ???) - ??? 2024 (month ???).
# $$\text{Rate of Change (second 2 months)} = \frac{\text{change in output}}{\text{change in input}} = \frac{???}{???} = ???$$

# %%
#have Python do the math
final_input_val = 2
start_input_val = 1
final_output_val = 5
start_output_val = 3
RoC_second_2 = compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val)
print("The Rate of Change (second 2 months) is equal to {}".format(RoC_second_2))
# Out:
# The Rate of Change (second 2 months) is equal to 2.0

# %% [markdown]
# The third 2 month interval is ??? 2024 (month ???) - ??? 2025 (month ???).
# $$\text{Rate of Change (third 2 months)} = \frac{\text{change in output}}{\text{change in input}} = \frac{???}{???} = ???$$

# %%
#have Python do the math
final_input_val = 2
start_input_val = 1
final_output_val = 5
start_output_val = 3
RoC_third_2 = compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val)
print("The Rate of Change (third 2 months) is equal to {}".format(RoC_third_2))
# Out:
# The Rate of Change (third 2 months) is equal to 2.0

# %% [markdown]
# The fourth 2 month interval is ??? 2025 (month ???) - ??? 2025 (month ???).
# $$\text{Rate of Change (fourth 2 months)} = \frac{\text{change in output}}{\text{change in input}} = \frac{???}{???} = ???$$

# %%
#have Python do the math
final_input_val = 2
start_input_val = 1
final_output_val = 5
start_output_val = 3
RoC_fourth_2 = compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val)
print("The Rate of Change (fourth 2 months) is equal to {}".format(RoC_fourth_2))
# Out:
# The Rate of Change (fourth 2 months) is equal to 2.0

# %% [markdown]
# The fifth 2 month interval is ??? 2025 (month ???) - ??? 2025 (month ???).
# $$\text{Rate of Change (fifth 2 months)} = \frac{\text{change in output}}{\text{change in input}} = \frac{???}{???} = ???$$

# %%
#have Python do the math
final_input_val = 2
start_input_val = 1
final_output_val = 5
start_output_val = 3
RoC_fifth_2 = compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val)
print("The Rate of Change (fifth 2 months) is equal to {}".format(RoC_fifth_2))
# Out:
# The Rate of Change (fifth 2 months) is equal to 2.0

# %% [markdown]
# The sixth 2 month interval is ??? 2025 (month ???) - ??? 2025 (month ???).
# $$\text{Rate of Change (sixth 2 months)} = \frac{\text{change in output}}{\text{change in input}} = \frac{???}{???} = ???$$

# %%
#have Python do the math
final_input_val = 2
start_input_val = 1
final_output_val = 5
start_output_val = 3
RoC_sixth_2 = compute_RoC_func(final_input_val,start_input_val,final_output_val,start_output_val)
print("The Rate of Change (sixth 2 months) is equal to {}".format(RoC_sixth_2))
# Out:
# The Rate of Change (sixth 2 months) is equal to 2.0

# %% [markdown]
# <b>Exercise 2.1.2:<b>
#
# (D) On which intervals is the average rate of change positive? Negative? Smaller? Larger? What do these changes tell you about what is happening with the amount of water in storage throughout
# the year?
